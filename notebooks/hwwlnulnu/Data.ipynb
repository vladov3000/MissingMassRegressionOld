# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df = pd.read_pickle("../../hwwlnulnu/data/h_ww_lnulnu.pkl")

# %%
df
# Out:
#           H_Mass  H_Genx  H_Geny       H_Genz       H_GenE      H_Genm  \
# 0          225.0     0.0     0.0  1095.271484  1118.929077  228.872650
# 1          225.0    -0.0     0.0  -671.841614   705.656128  215.822525
# 2          225.0     0.0     0.0 -1485.412842  1502.563965  226.378250
# 3          225.0     0.0     0.0  -280.013855   361.227264  228.204681
# 4          225.0    -0.0     0.0  -987.724487  1014.600220  231.978210
# ...          ...     ...     ...          ...          ...         ...
# 16499995   425.0     0.0    -0.0 -2303.529785  2342.699707  426.605225
# 16499996   425.0     0.0    -0.0  1432.436768  1495.426392  429.447083
# 16499997   425.0    -0.0    -0.0   568.095093   708.474609  423.325165
# 16499998   425.0    -0.0    -0.0   -29.227676   427.600922  426.600861
# 16499999   425.0    -0.0     0.0   375.424805   570.895203  430.090149
#
#           H_Genm_squared     Wa_Genx     Wa_Geny     Wa_Genz     Wa_GenE  \
# ...

# %%
display(df["La_Vism"].value_counts())
display(df["Lb_Vism"].value_counts())
# Out:
# 0.106    16439058
# 0.106       49809
# 0.106       10632
# 0.106         334
# 0.106         162
# 0.106           4
# 0.106           1
# Name: La_Vism, dtype: int64
# 0.106    16439599
# 0.106       49268
# 0.106       10647
# 0.106         312
# 0.106         169
# 0.106           3
# 0.106           2
# Name: Lb_Vism, dtype: int64

# %%
print(df.columns.to_list())
# Out:
# ['H_Mass', 'H_Genx', 'H_Geny', 'H_Genz', 'H_GenE', 'H_Genm', 'H_Genm_squared', 'Wa_Genx', 'Wa_Geny', 'Wa_Genz', 'Wa_GenE', 'Wa_Genm', 'Wa_Genm_squared', 'Wb_Genx', 'Wb_Geny', 'Wb_Genz', 'Wb_GenE', 'Wb_Genm', 'Wb_Genm_squared', 'La_Visx', 'La_Visy', 'La_Visz', 'La_VisE', 'La_Vism', 'La_Vism_squared', 'Na_Genx', 'Na_Geny', 'Na_Genz', 'Na_GenE', 'Na_Genm', 'Na_Genm_squared', 'Lb_Visx', 'Lb_Visy', 'Lb_Visz', 'Lb_VisE', 'Lb_Vism', 'Lb_Vism_squared', 'Nb_Genx', 'Nb_Geny', 'Nb_Genz', 'Nb_GenE', 'Nb_Genm', 'Nb_Genm_squared', 'MET_X_Vis', 'MET_Y_Vis', 'Hx', 'Hy', 'Hz', 'HE', 'Hm', 'Hm_squared', 'Wax', 'Way', 'Waz', 'WaE', 'Wam', 'Wam_squared', 'Wbx', 'Wby', 'Wbz', 'WbE', 'Wbm', 'Wbm_squared', 'Nax', 'Nay', 'Naz', 'NaE', 'Nam', 'Nam_squared', 'Nbx', 'Nby', 'Nbz', 'NbE', 'Nbm', 'Nbm_squared']

# %%
# input features: La_Visx, La_Visy, La_Visz, Lb_Visx, Lb_Visz, Lb_Visz, MET_X_Vis, MET_Y_Vis
# targets for net predictions: Na_Genx, Na_Geny, Na_Genz, Nb_Genz
# forward
# MSE loss out
# opt
# W boson loss (square mass)
# opt
# H loss (square mass)
# opt

# %%
import torch
print(torch.__version__)
# Out:
# 1.6.0
